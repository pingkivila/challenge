# %% [markdown]
# <a href="https://colab.research.google.com/github/pingkivila/challenge/blob/main/visualisasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import plotly.express as px
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from mpl_toolkits.mplot3d import Axes3D

plt.style.use('fivethirtyeight')
sns.set_style('white')
sns.set_context('notebook', font_scale=1.5, rc={'lines.linewidth':1.5})
# change the maximum width in characters of a column (default: 50)
pd.set_option('display.max_colwidth', None)
# change the display precision for better viz
pd.set_option('display.precision', 3)

# %% [markdown]
# # **CHALLENGE A START**

# %%
Chall_A_start = pd.read_csv('https://raw.githubusercontent.com/pingkivila/challenge/main/challenge%20A%20start.csv')
Chall_A_start
# Out:
#     No           Username                         Name  Total Action  \
# 0    1           AdrianiV                     AdrianiV             0
# 1    2      ahmadrivaldhi                ahmadrivaldhi             2
# 2    3        otniel.andi  otniel andi yogananda djoar             0
# 3    4     abigailtabitha              Abigail Tabitha             3
# 4    5          aisyahalf          Aisyah Putri Alifia             2
# ..  ..                ...                          ...           ...
# 85  86    anggikrisdianto       Anggi Krisdianto, S.Si             7
# 86  87  williamatcampaign          William Gondokusumo             7
# 87  88    kamiliyanabilah             kamiliya nabilah             3
# 88  89    hawin_nurhayati              Hawin Nurhayati             7
# 89  90           almirazn          Almira Zahranabella             0
#
#    Start Date Challenge
# 0             4/24/2022
# 1             4/22/2022
# 2             4/21/2022
# 3             4/20/2022
# ...

# %%
Chall_A_start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   No                    90 non-null     int64
#  1   Username              90 non-null     object
#  2   Name                  90 non-null     object
#  3   Total Action          90 non-null     int64
#  4   Start Date Challenge  90 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 3.6+ KB

# %%
Chall_A_start.describe()
# Out:
#            No  Total Action
# count  90.000        90.000
# mean   45.500         2.989
# std    26.125         2.909
# min     1.000         0.000
# 25%    23.250         0.000
# 50%    45.500         2.000
# 75%    67.750         7.000
# max    90.000         7.000

# %%
Chall_A_start.shape
# Out:
# (90, 5)

# %%
Chall_A_start.rename(columns={"Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Completed Date Challenge": "Completed_Date_Challenge"}, inplace=True)

Chall_A_start.head(5)
# Out:
#    No        Username                         Name  Total_Action  \
# 0   1        AdrianiV                     AdrianiV             0
# 1   2   ahmadrivaldhi                ahmadrivaldhi             2
# 2   3     otniel.andi  otniel andi yogananda djoar             0
# 3   4  abigailtabitha              Abigail Tabitha             3
# 4   5       aisyahalf          Aisyah Putri Alifia             2
#
#   Start_Date_Challenge
# 0            4/24/2022
# 1            4/22/2022
# 2            4/21/2022
# 3            4/20/2022
# 4            4/18/2022

# %% [markdown]
# # **CHALLENGE A COMPLATE**

# %%
Chall_A_comp = pd.read_csv('https://raw.githubusercontent.com/pingkivila/challenge/main/challenge%20A%20complet.csv')
Chall_A_comp
# Out:
#     No               Username                     Name  Total Action  \
# 0    1          romi_juniawan            Romi Juniawan             7
# 1    2               adrianiv                 AdrianiV             7
# 2    3         abigailtabitha          Abigail Tabitha             7
# 3    4             tanpratama            intan_pratama             7
# 4    5      febriantomulyawan        febriantomulyawan             7
# 5    6               nov_lisa              Novela Lisa             7
# 6    7                alfiaaf             Alfia Azizah             7
# 7    8                janna14                  janna14             7
# 8    9                 aunaza           Aun Syahrulloh             7
# 9   10            intankagome     Intan Kagome Siagian             7
# 10  11             windanetto           Winda Agusthia             7
# 11  12                  cdjap          Chrestecia Djap             7
# 12  13              nblittaqi            Nabila Ittaqi             7
# ...

# %%
Chall_A_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No                        30 non-null     int64
#  1   Username                  30 non-null     object
#  2   Name                      30 non-null     object
#  3   Total Action              30 non-null     int64
#  4   Start Date Challenge      30 non-null     object
#  5   Completed Date Challenge  30 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.5+ KB

# %%
Chall_A_comp.describe()
# Out:
#            No  Total Action
# count  30.000          30.0
# mean   15.500           7.0
# std     8.803           0.0
# min     1.000           7.0
# 25%     8.250           7.0
# 50%    15.500           7.0
# 75%    22.750           7.0
# max    30.000           7.0

# %%
Chall_A_comp.shape
# Out:
# (30, 6)

# %%
Chall_A_comp.rename(columns={"Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Completed Date Challenge": "Completed_Date_Challenge"}, inplace=True)

Chall_A_comp.head(5)
# Out:
#    No           Username               Name  Total_Action  \
# 0   1      romi_juniawan      Romi Juniawan             7
# 1   2           adrianiv           AdrianiV             7
# 2   3     abigailtabitha    Abigail Tabitha             7
# 3   4         tanpratama      intan_pratama             7
# 4   5  febriantomulyawan  febriantomulyawan             7
#
#   Start_Date_Challenge Completed_Date_Challenge
# 0            26-Apr-22                05-May-22
# 1            24-Apr-22                06-May-22
# 2            20-Apr-22                02-May-22
# 3            10-Apr-22                16-Apr-22
# 4            10-Apr-22                20-Apr-22

# %% [markdown]
# # **CHALLENGE B START**

# %%
Chall_B_start = pd.read_csv('https://raw.githubusercontent.com/pingkivila/challenge/main/challenge%20B%20start.csv')
Chall_B_start
# Out:
#       No                           Username  \
# 0      1                 yatimmandiri.kudus
# 1      2                      taniapriutomo
# 2      3                        intankagome
# 3      4                     malaka_lestari
# 4      5         rizkyputro31-1643801088876
# ..   ...                                ...
# 184  185                           ajmlana2
# 185  186                          fauzanmdd
# 186  187                           riaajryh
# 187  188      matthewpangeran-1643803025534
# 188  189  rosedesyantianwar31-1645793896636
#
#                                   Name  Total Action Start Date Challenge
# 0                  Yatim Mandiri Kudus             4           02/02/2022
# 1                       Tania Priutomo             4           02/02/2022
# 2                 Intan Kagome Siagian             4           02/02/2022
# 3                       malaka lestari             4           02/02/2022
# ...

# %%
Chall_B_start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   No                    189 non-null    int64
#  1   Username              189 non-null    object
#  2   Name                  189 non-null    object
#  3   Total Action          189 non-null    int64
#  4   Start Date Challenge  189 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.5+ KB

# %%
Chall_B_start.describe()
# Out:
#             No  Total Action
# count  189.000       189.000
# mean    95.000         3.132
# std     54.704         1.536
# min      1.000         0.000
# 25%     48.000         3.000
# 50%     95.000         4.000
# 75%    142.000         4.000
# max    189.000         4.000

# %%
Chall_B_start.shape
# Out:
# (189, 5)

# %%
Chall_B_start.rename(columns={"Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Completed Date Challenge": "Completed_Date_Challenge"}, inplace=True)

Chall_B_start.head(5)
# Out:
#    No                    Username                        Name  Total_Action  \
# 0   1          yatimmandiri.kudus         Yatim Mandiri Kudus             4
# 1   2               taniapriutomo              Tania Priutomo             4
# 2   3                 intankagome        Intan Kagome Siagian             4
# 3   4              malaka_lestari              malaka lestari             4
# 4   5  rizkyputro31-1643801088876  rizkyputro31-1643801088876             3
#
#   Start_Date_Challenge
# 0           02/02/2022
# 1           02/02/2022
# 2           02/02/2022
# 3           02/02/2022
# 4           02/02/2022

# %% [markdown]
# # **CHALLENGE B COMPLATE**

# %%
Chall_B_comp = pd.read_csv('https://raw.githubusercontent.com/pingkivila/challenge/main/challenge%20B%20complate.csv')
Chall_B_comp
# Out:
#       No                                 Username  \
# 0      1                               sunardidod
# 1      2                              intankagome
# 2      3                                rizkiejoe
# 3      4  rizkiej.privateassignment-1643953836707
# 4      5                             yasminafifah
# ..   ...                                      ...
# 134  135                           desiamalia0312
# 135  136                                 ajmlana2
# 136  137                                fauzanmdd
# 137  138                                 riaajryh
# 138  139            matthewpangeran-1643803025534
#
#                                         Name  Total Action  \
# 0                               Dodi Sunardi             4
# 1                       Intan Kagome Siagian             4
# 2                                 Rizkie Joe             4
# 3    rizkiej.privateassignment-1643953836707             4
# 4                              Yasmin Afifah             4
# ...

# %%
Chall_B_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No                        139 non-null    int64
#  1   Username                  139 non-null    object
#  2   Name                      139 non-null    object
#  3   Total Action              139 non-null    int64
#  4   Start Date Challenge      139 non-null    object
#  5   Completed Date Challenge  139 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 6.6+ KB

# %%
Chall_B_comp.describe()
# Out:
#            No  Total Action
# count  139.00         139.0
# mean    70.00           4.0
# std     40.27           0.0
# min      1.00           4.0
# 25%     35.50           4.0
# 50%     70.00           4.0
# 75%    104.50           4.0
# max    139.00           4.0

# %%
Chall_B_comp.rename(columns={"Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Total Action": "Total_Action", 
                        "Start Date Challenge": "Start_Date_Challenge",
                        "Completed Date Challenge": "Completed_Date_Challenge"}, inplace=True)

Chall_B_comp.head(5)
# Out:
#    No                                 Username  \
# 0   1                               sunardidod
# 1   2                              intankagome
# 2   3                                rizkiejoe
# 3   4  rizkiej.privateassignment-1643953836707
# 4   5                             yasminafifah
#
#                                       Name  Total_Action Start_Date_Challenge  \
# 0                             Dodi Sunardi             4           03/02/2022
# 1                     Intan Kagome Siagian             4           02/02/2022
# 2                               Rizkie Joe             4           04/02/2022
# 3  rizkiej.privateassignment-1643953836707             4           04/02/2022
# 4                            Yasmin Afifah             4           04/02/2022
#
#   Completed_Date_Challenge
# 0               03/02/2022
# 1               04/02/2022
# 2               04/02/2022
# 3               04/02/2022
# 4               04/02/2022

# %% [markdown]
# # **VISUALISASI**

# %% [markdown]
# **MERGE CHALLENGE A**

# %%
# gabungkan tabel challenge A start dengan challenge A complate
Chall_A = Chall_A_start.merge(Chall_A_comp, how='outer', on=['Name','Username'])
Chall_A.head(5)
# Out:
#    No_x        Username                         Name  Total Action_x  \
# 0   1.0        AdrianiV                     AdrianiV             0.0
# 1   2.0   ahmadrivaldhi                ahmadrivaldhi             2.0
# 2   3.0     otniel.andi  otniel andi yogananda djoar             0.0
# 3   4.0  abigailtabitha              Abigail Tabitha             3.0
# 4   5.0       aisyahalf          Aisyah Putri Alifia             2.0
#
#   Start Date Challenge_x  No_y  Total Action_y Start Date Challenge_y  \
# 0              4/24/2022   NaN             NaN                    NaN
# 1              4/22/2022   NaN             NaN                    NaN
# 2              4/21/2022   NaN             NaN                    NaN
# 3              4/20/2022   3.0             7.0              20-Apr-22
# 4              4/18/2022   NaN             NaN                    NaN
#
#   Completed Date Challenge
# 0                      NaN
# 1                      NaN
# 2                      NaN
# ...

# %%
Chall_A.shape
# Out:
# (92, 9)

# %%
Chall_A.rename(columns={"Total Action_x": "Total_Action_x", 
                        "Start Date Challenge_x": "Start_Date_Challenge_x",
                        "Total Action_y": "Total_Action_y", 
                        "Start Date Challenge_y": "Start_Date_Challenge_y",
                        "Completed Date Challenge": "Completed_Date_Challenge"}, inplace=True)

Chall_A.head(5)
# Out:
#    No_x        Username                         Name  Total_Action_x  \
# 0   1.0        AdrianiV                     AdrianiV             0.0
# 1   2.0   ahmadrivaldhi                ahmadrivaldhi             2.0
# 2   3.0     otniel.andi  otniel andi yogananda djoar             0.0
# 3   4.0  abigailtabitha              Abigail Tabitha             3.0
# 4   5.0       aisyahalf          Aisyah Putri Alifia             2.0
#
#   Start_Date_Challenge_x  No_y  Total_Action_y Start_Date_Challenge_y  \
# 0              4/24/2022   NaN             NaN                    NaN
# 1              4/22/2022   NaN             NaN                    NaN
# 2              4/21/2022   NaN             NaN                    NaN
# 3              4/20/2022   3.0             7.0              20-Apr-22
# 4              4/18/2022   NaN             NaN                    NaN
#
#   Completed_Date_Challenge
# 0                      NaN
# 1                      NaN
# 2                      NaN
# ...

# %% [markdown]
# **MERGE CHALLENGE B**

# %%
# gabungkan tabel challenge B start dengan challenge B complate
Chall_B = Chall_B_start.merge(Chall_B_comp, how='outer', on=['Name','Username'])
Chall_B
# Out:
#      No_x                           Username  \
# 0       1                 yatimmandiri.kudus
# 1       2                      taniapriutomo
# 2       3                        intankagome
# 3       4                     malaka_lestari
# 4       5         rizkyputro31-1643801088876
# ..    ...                                ...
# 184   185                           ajmlana2
# 185   186                          fauzanmdd
# 186   187                           riaajryh
# 187   188      matthewpangeran-1643803025534
# 188   189  rosedesyantianwar31-1645793896636
#
#                                   Name  Total Action_x Start Date Challenge_x  \
# 0                  Yatim Mandiri Kudus               4             02/02/2022
# 1                       Tania Priutomo               4             02/02/2022
# 2                 Intan Kagome Siagian               4             02/02/2022
# 3                       malaka lestari               4             02/02/2022
# ...

# %%
Chall_B.shape
# Out:
# (189, 9)

# %%
Chall_B.rename(columns={"Total Action_x": "Total_Action_x", 
                        "Start Date Challenge_x": "Start_Date_Challenge_x",
                        "Total Action_y": "Total_Action_y", 
                        "Start Date Challenge_y": "Start_Date_Challenge_y",
                        "Completed Date Challenge": "Completed_Date_Challenge"}, inplace=True)

Chall_B.head(50)
# Out:
#     No_x                                 Username  \
# 0      1                       yatimmandiri.kudus
# 1      2                            taniapriutomo
# 2      3                              intankagome
# 3      4                           malaka_lestari
# 4      5               rizkyputro31-1643801088876
# 5      6              susar.djanadi-1643805073793
# 6      7                              nurulafiyah
# 7      8              cingulomania9-1643806658188
# 8      9                                  maxines
# 9     10                                   delrey
# 10    11                               sunardidod
# 11    12                              farahhanifa
# 12    13                                  nabskoy
# 13    14                          itrindianamozez
# 14    15                   sitifatimahayuningdyah
# 15    16                                  asagaea
# 16    17                              ladyapniken
# 17    18                                rizkiejoe
# ...

# %%
Chall_A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92 entries, 0 to 91
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No_x                      90 non-null     float64
#  1   Username                  92 non-null     object
#  2   Name                      92 non-null     object
#  3   Total_Action_x            90 non-null     float64
#  4   Start_Date_Challenge_x    90 non-null     object
#  5   No_y                      30 non-null     float64
#  6   Total_Action_y            30 non-null     float64
#  7   Start_Date_Challenge_y    30 non-null     object
#  8   Completed_Date_Challenge  30 non-null     object
# dtypes: float64(4), object(5)
# memory usage: 7.2+ KB

# %%
Chall_A_start['Total_Action'].value_counts().plot(kind='barh')

# %%
Chall_A['Total_Action_x'].value_counts().plot(kind='barh')

# %%
Chall_B_start['Total_Action'].value_counts().plot(kind='barh')

# %%
pie_data = Chall_A['Total_Action_x'].value_counts(normalize=True).values * 100
pie_label = Chall_A['Total_Action_x'].value_counts(normalize=True).index.to_list()

fig, ax = plt.subplots(figsize=(8,6))

wedges, texts, autotexts = ax.pie(pie_data, labels=pie_label,
                                  startangle=90,
                                  autopct='%.0f%%',
                                  textprops={'color':'w', 'fontsize':16, 'weight':'bold'})

for i, wedge in enumerate(wedges):
  texts[i].set_color(wedge.get_facecolor())

plt.tight_layout()

# %%
pie_data = Chall_B['Total_Action_x'].value_counts(normalize=True).values * 100
pie_label = Chall_B['Total_Action_x'].value_counts(normalize=True).index.to_list()

fig, ax = plt.subplots(figsize=(8,6))

wedges, texts, autotexts = ax.pie(pie_data, labels=pie_label,
                                  startangle=90,
                                  autopct='%.0f%%',
                                  textprops={'color':'w', 'fontsize':16, 'weight':'bold'})

for i, wedge in enumerate(wedges):
  texts[i].set_color(wedge.get_facecolor())

plt.tight_layout()
